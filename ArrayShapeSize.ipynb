# %%
import numpy as np

# %%
first_array = np.arange(20)
first_array

# %%
second_array = np.linspace((1,2),(10,20),10)
second_array

# %%
third_array= np.full((2,2,2),10)
third_array

# %%
np.shape(first_array)

# %%
np.shape(second_array)

# %%
np.shape(third_array)

# %%
np.size(first_array)

# %%
np.size(second_array)
# Out:
# 20

# %%
np.size(third_array)
# Out:
# 8
