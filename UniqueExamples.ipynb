# %%
import numpy as np

# %%
first_arr = np.array([1,2,3,4,5,6,1,2,7,2,1,10,7,8])

# %%
np.unique(first_arr)
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7,  8, 10])

# %%
second_arr = ([[1,1,2,1],[3,1,2,1],[1,1,2,1],[7,1,1,1]])
second_arr
# Out:
# [[1, 1, 2, 1], [3, 1, 2, 1], [1, 1, 2, 1], [7, 1, 1, 1]]

# %%
np.unique(second_arr)
# Out:
# array([1, 2, 3, 7])

# %%
np.unique(second_arr, axis=0)
# Out:
# array([[1, 1, 2, 1],
#        [3, 1, 2, 1],
#        [7, 1, 1, 1]])

# %%
np.unique(second_arr, axis=1)
# Out:
# array([[1, 1, 2],
#        [1, 3, 2],
#        [1, 1, 2],
#        [1, 7, 1]])

# %%
np.unique(first_arr, return_index=True)
# Out:
# (array([ 1,  2,  3,  4,  5,  6,  7,  8, 10]),
#  array([ 0,  1,  2,  3,  4,  5,  8, 13, 11]))

# %%
np.unique(second_arr, return_index=True)
# Out:
# (array([1, 2, 3, 7]), array([ 0,  2,  4, 12]))

# %%
np.unique(second_arr, return_countsz=True)
# Out:
# (array([1, 2, 3, 7]), array([11,  3,  1,  1]))
