# %%
import numpy as np

# %%
integer_array = np.array([10,20,30,40,50])
print(integer_array)
# Out:
# [10 20 30 40 50]

# %%
integer_array[0]
# Out:
# np.int64(10)

# %%
integer_array.dtype
# Out:
# dtype('int64')

# %%
second_integer_array = np.array(integer_array,dtype=np.int8)
second_integer_array
# Out:
# array([10, 20, 30, 40, 50], dtype=int8)

# %%
integer_array.nbytes
# Out:
# 40

# %%
second_integer_array.nbytes
# Out:
# 5
